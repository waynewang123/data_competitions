# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import timedelta
import lightgbm as lgb
import seaborn as sns

# %%
demand = pd.read_csv('demand_train.csv')
stock = pd.read_csv('stock_train.csv')
sample_submission = pd.read_csv("提交结果模板.csv",encoding = 'gb18030')

# %%
sample_submission
# Out:
#    工厂编码  物料编码  M+1月预测需求量  M+2月预测需求量  M+3月预测需求量
# 0  2001  1001          1          2          3
# 1  2002  1002          2          3          2

# %%
demand_cols_mapping = {
    '过账日期':'date',
    '需求量':'demand_amount',
    '工厂编码':'factory_code',
    '物料编码':'material_code',
    '物料品牌':'material_brand',
    '物料类型':'material_type',
    '物料品类':'material_category'
}
stock_cols_mapping = {
    '过账日期':'date',
    '库存量':'storage_amount',
    '工厂编码':'factory_code',
    '物料编码':'material_code',
    '物料品牌':'material_brand',
    '物料类型':'material_type',
    '物料品类':'material_category'
}

# %%
demand = demand.rename(columns = demand_cols_mapping)
stock = stock.rename(columns = stock_cols_mapping)
demand['date'] = pd.to_datetime(demand['date'])
stock['date'] = pd.to_datetime(stock['date'])

# %%
demand.head()
# Out:
#         date  demand_amount  factory_code  material_code  material_brand  \
# 0 2018-01-06           0.33          2004           1000            5000
# 1 2018-01-08           0.09          2010           1000            5000
# 2 2018-01-09           0.09          2008           1000            5000
# 3 2018-01-10           0.10          2010           1000            5000
# 4 2018-01-11           0.17          2004           1000            5000
#
#    material_type  material_category
# 0           3002               4014
# 1           3002               4014
# 2           3002               4014
# 3           3002               4014
# 4           3002               4014

# %%
stock.head()
# Out:
#         date  factory_code  material_code  material_brand  material_type  \
# 0 2018-01-24          2000           1001            5000           3002
# 1 2018-01-24          2000           1003            5000           3002
# 2 2018-01-24          2000           1014            5000           3002
# 3 2018-01-24          2000           1021            5000           3002
# 4 2018-01-24          2000           1027            5001           3002
#
#    material_category  storage_amount
# 0               4006            2.71
# 1               4005            6.84
# 2               4008            1.28
# 3               4006            1.04
# 4               4014            2.63

# %%
demand_df = demand.groupby(['date','factory_code','material_code'],as_index = False)['demand_amount'].sum()

# %%
stock_df = stock.groupby(['date','factory_code','material_code'],as_index = False)['storage_amount'].sum()

# %%
demand_df.head()
# Out:
#         date  factory_code  material_code  demand_amount
# 0 2018-01-01          2001           1029           1.29
# 1 2018-01-01          2001           1051           0.09
# 2 2018-01-01          2001           1054           0.70
# 3 2018-01-01          2001           1159           1.24
# 4 2018-01-01          2001           1167           6.40

# %%
demand_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 248503 entries, 0 to 248502
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   date           248503 non-null  datetime64[ns]
#  1   factory_code   248503 non-null  int64
#  2   material_code  248503 non-null  int64
#  3   demand_amount  248503 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 9.5 MB

# %% [markdown]
# ## EDA

# %%
# Look at the data
plt.figure(figsize=(12, 8))
plt.plot(demand_df[(demand_df.factory_code == 2001) & (demand_df.material_code == 1029)]['demand_amount'].diff())
plt.title("Train data for factory 2001:material 1029")
plt.show()

# %%
demand_df.date.min(),demand_df.date.max()
# Out:
# (Timestamp('2018-01-01 00:00:00'), Timestamp('2020-11-24 00:00:00'))

# %%
train = demand_df.copy()

# %%
factory_list = pd.DataFrame(demand_df.factory_code.unique(),columns = ['factory_code'])
material_list = pd.DataFrame(demand_df.material_code.unique(),columns = ['material_code'])

# %%
factory_list['outer_join_key'] = '0'
material_list['outer_join_key'] = '0'

# %%
tmp = factory_list.merge(material_list, how = 'outer',on = 'outer_join_key')

# %%
date1 = pd.DataFrame(pd.date_range(start='11/25/2020', end='2/28/2021'),columns = ['date'])
date1['outer_join_key'] = '0'

# %%
date1.head()
# Out:
#         date outer_join_key
# 0 2020-11-25              0
# 1 2020-11-26              0
# 2 2020-11-27              0
# 3 2020-11-28              0
# 4 2020-11-29              0

# %%
test = date1.merge(tmp,on = 'outer_join_key',how = 'outer')

# %%
test = test.drop(columns = 'outer_join_key')

# %%
test['demand_amount'] = 0
test.head()
# Out:
#         date  factory_code  material_code  demand_amount
# 0 2020-11-25          2001           1029              0
# 1 2020-11-25          2001           1051              0
# 2 2020-11-25          2001           1054              0
# 3 2020-11-25          2001           1159              0
# 4 2020-11-25          2001           1167              0

# %%
train.tail()
# Out:
#              date  factory_code  material_code  demand_amount
# 248498 2020-11-24          2015           1083           0.88
# 248499 2020-11-24          2015           1089           9.36
# 248500 2020-11-24          2015           1090           0.60
# 248501 2020-11-24          2015           1091          50.96
# 248502 2020-11-24          2015           1252           0.48

# %%
# Set date to the index
train['date'] = pd.to_datetime(train['date'])
train.set_index(["date"], inplace=True)

test['date'] = pd.to_datetime(test['date'])
test.set_index(["date"], inplace=True)

# %% [markdown]
# ## Feature engineering

# %%
def get_date_features(df):
    
    # Add date-specific features
    df['dayofweek'] = df.index.dayofweek
    df['is_weekend'] = df.index.dayofweek // 5
    df['day'] = df.index.day
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['weekofyear'] = df.index.weekofyear

    return df

# %%
def generate_features(train, test):

    # Get the time delta between last test and last train observations
    model_delta = max(test.index) - max(train.index)

    # Initialize variables
    lags = [model_delta.days]
    window = 7
    lag_features = []

    # Concatenate train and test together
    data = pd.concat([train, test], sort=False)

    for lag in lags:
        feat = data.groupby(["factory_code", "material_code"])[["demand_amount"]].rolling(window=window).mean().shift(lag)
        feat.columns = ['demand_mean_lag_{}'.format(lag)]
        lag_features.append(feat)

        feat = data.groupby(["factory_code", "material_code"])[["demand_amount"]].rolling(window=window).std().shift(lag)
        feat.columns = ['demand_std_lag_{}'.format(lag)]
        lag_features.append(feat)

    # Concatenate all features together
    lag_features = pd.concat(lag_features, axis=1)

    # Add date features to the train and test
    train = get_date_features(train)
    test = get_date_features(test)

    # Join lag features to the train and test by (store, item, date)
    train.set_index(["factory_code", "material_code"], append=True, inplace=True)
    train = train.reorder_levels(["factory_code", "material_code", "date"])
    test.set_index(["factory_code", "material_code"], append=True, inplace=True)
    test = test.reorder_levels(["factory_code", "material_code", "date"])

    train = train.join(lag_features)
    test = test.join(lag_features)

    # Resetting index back
    train.reset_index(level=[0, 1], inplace=True)
    test.reset_index(level=[0, 1], inplace=True)
    
    return train, test, model_delta, window

# %%
# Generate some features
train, test, model_delta, window = generate_features(train, test)
# Out:
# <ipython-input-178-a6dab9ac47ed>:10: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df['weekofyear'] = df.index.weekofyear

# %%
train.tail()
# Out:
#             factory_code  material_code  demand_amount  dayofweek  is_weekend  \
# date
# 2020-11-24          2015           1083           0.88          1           0
# 2020-11-24          2015           1089           9.36          1           0
# 2020-11-24          2015           1090           0.60          1           0
# 2020-11-24          2015           1091          50.96          1           0
# 2020-11-24          2015           1252           0.48          1           0
#
#             day  month  year  dayofyear  weekofyear  demand_mean_lag_96  \
# date
# 2020-11-24   24     11  2020        329          48            1.662857
# 2020-11-24   24     11  2020        329          48            4.725714
# 2020-11-24   24     11  2020        329          48            1.074286
# 2020-11-24   24     11  2020        329          48           21.680000
# 2020-11-24   24     11  2020        329          48            0.948571
#
#             demand_std_lag_96
# date
# ...

# %%
test.head()
# Out:
#             factory_code  material_code  demand_amount  dayofweek  is_weekend  \
# date
# 2020-11-25          2001           1029              0          2           0
# 2020-11-25          2001           1051              0          2           0
# 2020-11-25          2001           1054              0          2           0
# 2020-11-25          2001           1159              0          2           0
# 2020-11-25          2001           1167              0          2           0
#
#             day  month  year  dayofyear  weekofyear  demand_mean_lag_96  \
# date
# 2020-11-25   25     11  2020        330          48            1.971429
# 2020-11-25   25     11  2020        330          48            3.057143
# 2020-11-25   25     11  2020        330          48            4.960000
# 2020-11-25   25     11  2020        330          48           10.080000
# 2020-11-25   25     11  2020        330          48            9.114286
#
#             demand_std_lag_96
# date
# ...

# %%
# Train start date
start = min(train.index) + model_delta + timedelta(days=window)

# Validation start date
split_date = max(train.index) - model_delta

# Keep only non-NA values in the train data
train = train[train.index >= start]

# Train-Validation split
val_train = train[train.index < split_date]
validation = train[train.index > split_date]

# %%
def smape(y_true, y_pred):
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    diff = 100 * np.abs(y_true - y_pred) / denominator
    diff[denominator == 0] = 0.0
    
    return np.nanmean(diff)


def smape_lightgbm(y_pred, y_true):
    return "smape", smape(y_true, y_pred), False

# %%
# Select all the features except for the target variable
features = [x for x in train.columns if x != "demand_amount"]

params = {
    "learning_rate": 0.1,
    "objective": "regression",
    "metric": "None",
    "n_estimators": 1000,
    "colsample_bytree": 0.9,
    "num_leaves": 32,
    "subsample": 0.8,
    "subsample_freq": 1,
    "lambda_l2": 1,
}

# Train LightGBM model
reg = lgb.LGBMRegressor(**params)
reg = reg.fit(
    val_train[features],
    val_train["demand_amount"],
    eval_set=[(validation[features], validation["demand_amount"])],
    verbose=100,
    early_stopping_rounds=200,
    eval_metric=smape_lightgbm,
)
# Out:
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1
# Training until validation scores don't improve for 200 rounds
# [100]	valid_0's smape: 73.7704
# [200]	valid_0's smape: 71.9693
# [300]	valid_0's smape: 71.3376
# [400]	valid_0's smape: 71.3092
# [500]	valid_0's smape: 71.1319
# [600]	valid_0's smape: 71.2119
# [700]	valid_0's smape: 71.0436
# [800]	valid_0's smape: 70.8098
# [900]	valid_0's smape: 70.7569
# [1000]	valid_0's smape: 70.7684
# Did not meet early stopping. Best iteration is:
# [978]	valid_0's smape: 70.7369

# %%
##predict the model
predictions = reg.predict(validation[features])
validation['pred'] = predictions
print("Validation SMAPE: {:.3f}".format(smape(validation["demand_amount"], validation["pred"])))
# Out:
# Validation SMAPE: 70.737
# <ipython-input-186-bda9ab116894>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation['pred'] = predictions

# %%
plt.figure(figsize=(12, 8))

to_plot = validation[(validation.factory_code==2000) & (validation.material_code==1027)]

plt.plot(to_plot["demand_amount"], alpha=0.8)
plt.plot(to_plot["pred"], linestyle="--")
plt.title("True values vs Predicted values for store 1; item 1")
plt.legend(["TRUE VALUES", "PREDICTED VALUES"])
plt.xticks(None)
plt.show()

# %%
# Re-train the model on the whole train data
params['n_estimators'] = reg.best_iteration_

# Train LightGBM model
reg = lgb.LGBMRegressor(**params)
reg = reg.fit(
    train[features],
    train["demand_amount"],
)
# Out:
# [LightGBM] [Warning] lambda_l2 is set=1, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1

# %%
feature_importances = pd.DataFrame(
    {"feature": val_train[features].columns,
     "importance": reg.feature_importances_}
)

plt.figure(figsize=(8, 8))
sns.barplot(
    data=feature_importances.sort_values("importance", ascending=False).head(10),
    x="importance",
    y="feature",
)
plt.yticks(fontsize=14)
plt.title("Top 10 features")
plt.show()

# %%
test.head()
# Out:
#             factory_code  material_code  demand_amount  dayofweek  is_weekend  \
# date
# 2020-11-25          2001           1029              0          2           0
# 2020-11-25          2001           1051              0          2           0
# 2020-11-25          2001           1054              0          2           0
# 2020-11-25          2001           1159              0          2           0
# 2020-11-25          2001           1167              0          2           0
#
#             day  month  year  dayofyear  weekofyear  demand_mean_lag_96  \
# date
# 2020-11-25   25     11  2020        330          48            1.971429
# 2020-11-25   25     11  2020        330          48            3.057143
# 2020-11-25   25     11  2020        330          48            4.960000
# 2020-11-25   25     11  2020        330          48           10.080000
# 2020-11-25   25     11  2020        330          48            9.114286
#
#             demand_std_lag_96
# date
# ...

# %%
## fill minus 0 value with 0
def fill_minus(x):
    if x < 0:
        x = 0
    return x

# %%
test["demand_amount"] = reg.predict(test[features])
test['demand_amount'] = test['demand_amount'].apply(lambda x:fill_minus(x))

# %%
test.head()
# Out:
#             factory_code  material_code  demand_amount  dayofweek  is_weekend  \
# date
# 2020-11-25          2001           1029       3.060188          2           0
# 2020-11-25          2001           1051       4.308037          2           0
# 2020-11-25          2001           1054      13.995459          2           0
# 2020-11-25          2001           1159       0.000000          2           0
# 2020-11-25          2001           1167       2.708090          2           0
#
#             day  month  year  dayofyear  weekofyear  demand_mean_lag_96  \
# date
# 2020-11-25   25     11  2020        330          48            1.971429
# 2020-11-25   25     11  2020        330          48            3.057143
# 2020-11-25   25     11  2020        330          48            4.960000
# 2020-11-25   25     11  2020        330          48           10.080000
# 2020-11-25   25     11  2020        330          48            9.114286
#
#             demand_std_lag_96
# date
# ...

# %%
plt.figure(figsize=(12, 8))
plt.plot(train[(train.factory_code==2001) & (train.material_code==1029)][["demand_amount"]])
plt.plot(test[(test.factory_code==2001) & (test.material_code==1029)][["demand_amount"]])
plt.title("Train data and Test predictions for store 1; item 1")
plt.legend(["TRAIN", "TEST"])
plt.show()

# %%
test.head()
# Out:
#             factory_code  material_code  demand_amount  dayofweek  is_weekend  \
# date
# 2020-11-25          2001           1029       3.060188          2           0
# 2020-11-25          2001           1051       4.308037          2           0
# 2020-11-25          2001           1054      13.995459          2           0
# 2020-11-25          2001           1159       0.000000          2           0
# 2020-11-25          2001           1167       2.708090          2           0
#
#             day  month  year  dayofyear  weekofyear  demand_mean_lag_96  \
# date
# 2020-11-25   25     11  2020        330          48            1.971429
# 2020-11-25   25     11  2020        330          48            3.057143
# 2020-11-25   25     11  2020        330          48            4.960000
# 2020-11-25   25     11  2020        330          48           10.080000
# 2020-11-25   25     11  2020        330          48            9.114286
#
#             demand_std_lag_96
# date
# ...

# %%
submission = test.groupby(['factory_code','material_code','month'],as_index = False).demand_amount.sum()

# %%
submission.head()
# Out:
#    factory_code  material_code  month  demand_amount
# 0          2000           1000      1      55.624090
# 1          2000           1000      2      25.933709
# 2          2000           1000     11      20.188841
# 3          2000           1000     12      71.692481
# 4          2000           1001      1      57.110242

# %%
tmp1 = submission[submission.month.isin([12,1,2])]

# %%
tmp1.head()
# Out:
#    factory_code  material_code  month  demand_amount
# 0          2000           1000      1      55.624090
# 1          2000           1000      2      25.933709
# 3          2000           1000     12      71.692481
# 4          2000           1001      1      57.110242
# 5          2000           1001      2      74.834577

# %%
tmp2 = pd.DataFrame()
tmp2[['工厂编码','物料编码']] = tmp1[['factory_code','material_code']].drop_duplicates().reset_index(drop = True)

# %%
tmp2.head()
# Out:
#    工厂编码  物料编码
# 0  2000  1000
# 1  2000  1001
# 2  2000  1002
# 3  2000  1003
# 4  2000  1004

# %%
tmp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4704 entries, 0 to 18812
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   工厂编码    4704 non-null   int64
#  1   物料编码    4704 non-null   int64
# dtypes: int64(2)
# memory usage: 110.2 KB

# %%
tmp3 = tmp1.pivot(index=['factory_code','material_code'], columns='month', values='demand_amount')

# %%
tmp3 = tmp3.rename(columns = {12:'M+1月预测需求量',1:'M+2月预测需求量',2:'M+3月预测需求量'}).reset_index(drop = True)

# %%
tmp3[['M+1月预测需求量','M+2月预测需求量','M+3月预测需求量']]
# Out:
# month   M+1月预测需求量   M+2月预测需求量   M+3月预测需求量
# 0       71.692481   55.624090   25.933709
# 1       95.148595   57.110242   74.834577
# 2      160.100241   84.152692   86.929900
# 3      186.013470  139.658856  136.588577
# 4      216.211096   87.208844   90.110313
# ...           ...         ...         ...
# 4699   188.162145  154.437987   88.111831
# 4700   188.162145  154.437987   88.111831
# 4701   188.162145  154.437987   88.111831
# 4702   199.740338  164.148729   94.087673
# 4703   199.740338  164.148729   94.087673
#
# [4704 rows x 3 columns]

# %%
tmp2 = pd.concat([tmp2,tmp3[['M+1月预测需求量','M+2月预测需求量','M+3月预测需求量']]],axis = 1)

# %%
tmp2.head()
# Out:
#    工厂编码  物料编码   M+1月预测需求量   M+2月预测需求量   M+3月预测需求量
# 0  2000  1000   71.692481   55.624090   25.933709
# 1  2000  1001   95.148595   57.110242   74.834577
# 2  2000  1002  160.100241   84.152692   86.929900
# 3  2000  1003  186.013470  139.658856  136.588577
# 4  2000  1004  216.211096   87.208844   90.110313

# %%
tmp2.to_csv('submission_v1.csv',encoding = 'gb18030')
